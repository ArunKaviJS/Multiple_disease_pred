# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# EDA FOR PARKINSON

# %%
df=pd.read_csv(r"C:\Users\firea\Downloads\parkinsons - parkinsons.csv")

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',25)
pd.set_option('display.width',200)

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784          0.000070   0.00370   0.00554     0.01109       0.04374             0.426       0.02182       0.03130   0.02971
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968          0.000080   0.00465   0.00696     0.01394       0.06134             0.626       0.03134       0.04518   0.04368
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050          0.000090   0.00544   0.00781     0.01633       0.05233             0.482       0.02757       0.03858   0.03590
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997          0.000090   0.00502   0.00698     0.01505       0.05492             0.517       0.02924       0.04005   0.03772
# ...

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
for i in list(df.columns)[1:]:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
for i in list(df.columns)[1:]:
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\firea\AppData\Local\Temp\ipykernel_18872\3409272564.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\firea\AppData\Local\Temp\ipykernel_18872\3409272564.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# ...

# %% [markdown]
# CHECKING CORRELATION

# %%
no_df=df.drop(['status','name'],axis=1)

# %%
plt.figure(figsize=(20,20))
corr=no_df.corr()
sns.heatmap(corr,annot=True,cmap='rainbow')
# Out:
# <Axes: >

# %% [markdown]
# WE HAVE GOT MINMAXSCALER RANGE [-0.75,1]

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# EVEN THERE IS NO NULL VALUES THERE CAN BE A NAN , SO WE HAVE TO CHECK if there is nan or others characters

# %%
for i in df.columns:
    print('********************************************',i,'***********************************************')
    print()
    print(df[i].unique())
    print()
# Out:
# ******************************************** name ***********************************************
#
# ['phon_R01_S01_1' 'phon_R01_S01_2' 'phon_R01_S01_3' 'phon_R01_S01_4'
#  'phon_R01_S01_5' 'phon_R01_S01_6' 'phon_R01_S02_1' 'phon_R01_S02_2'
#  'phon_R01_S02_3' 'phon_R01_S02_4' 'phon_R01_S02_5' 'phon_R01_S02_6'
#  'phon_R01_S04_1' 'phon_R01_S04_2' 'phon_R01_S04_3' 'phon_R01_S04_4'
#  'phon_R01_S04_5' 'phon_R01_S04_6' 'phon_R01_S05_1' 'phon_R01_S05_2'
#  'phon_R01_S05_3' 'phon_R01_S05_4' 'phon_R01_S05_5' 'phon_R01_S05_6'
#  'phon_R01_S06_1' 'phon_R01_S06_2' 'phon_R01_S06_3' 'phon_R01_S06_4'
#  'phon_R01_S06_5' 'phon_R01_S06_6' 'phon_R01_S07_1' 'phon_R01_S07_2'
#  'phon_R01_S07_3' 'phon_R01_S07_4' 'phon_R01_S07_5' 'phon_R01_S07_6'
#  'phon_R01_S08_1' 'phon_R01_S08_2' 'phon_R01_S08_3' 'phon_R01_S08_4'
#  'phon_R01_S08_5' 'phon_R01_S08_6' 'phon_R01_S10_1' 'phon_R01_S10_2'
#  'phon_R01_S10_3' 'phon_R01_S10_4' 'phon_R01_S10_5' 'phon_R01_S10_6'
# ...

# %% [markdown]
# EDA FOR PARKINSONS COMPLETED

# %% [markdown]
# ----------------------

# %% [markdown]
# EDA FOR KIDNEY DISEASE

# %%
df1=pd.read_csv(r"C:\Users\firea\Downloads\kidney_disease - kidney_disease.csv")

# %%
df1.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba    bgr    bu  ...  pot  hemo  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent  121.0  36.0  ...  NaN  15.4   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent    NaN  18.0  ...  NaN  11.3   38  6000  NaN   no   no  no  good   no   no            ckd
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0  53.0  ...  NaN   9.6   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0  56.0  ...  2.5  11.2   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# ...

# %%
pd.set_option('display.max_rows',400)
pd.set_option('display.max_columns',26)
pd.set_option('display.width',400)

# %%
df1
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc          ba    bgr     bu     sc    sod   pot  hemo  pcv     wc   rc  htn   dm  cad appet   pe  ane classification
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent  121.0   36.0   1.20    NaN   NaN  15.4   44   7800  5.2  yes  yes   no  good   no   no            ckd
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent    NaN   18.0   0.80    NaN   NaN  11.3   38   6000  NaN   no   no   no  good   no   no            ckd
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent  423.0   53.0   1.80    NaN   NaN   9.6   31   7500  NaN   no  yes   no  poor   no  yes            ckd
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent  117.0   56.0   3.80  111.0   2.5  11.2   32   6700  3.9  yes   no   no  poor  yes  yes            ckd
# ...

# %% [markdown]
# CHECKING OUTLIERS

# %%
for i in list(df1.columns):
    sns.boxplot(df1[i])
    plt.show()

# %%
#have to handle the outliers

# %% [markdown]
# CHECKING FOR NULL VALUES

# %%
df1.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %% [markdown]
# HAVE TO FILL NULL VALUES

# %%
feature=df1[['sc','bu','al','bp','hemo']]

# %%
feature
# Out:
#         sc     bu   al     bp  hemo
# 0     1.20   36.0  1.0   80.0  15.4
# 1     0.80   18.0  4.0   50.0  11.3
# 2     1.80   53.0  2.0   80.0   9.6
# 3     3.80   56.0  4.0   70.0  11.2
# 4     1.40   26.0  2.0   80.0  11.6
# 5     1.10   25.0  3.0   90.0  12.2
# 6    24.00   54.0  0.0   70.0  12.4
# 7     1.10   31.0  2.0    NaN  12.4
# 8     1.90   60.0  3.0  100.0  10.8
# 9     7.20  107.0  2.0   90.0   9.5
# 10    4.00   55.0  2.0   60.0   9.4
# 11    2.70   60.0  3.0   70.0  10.8
# 12    2.10   72.0  3.0   70.0   9.7
# 13    4.60   86.0  NaN   70.0   9.8
# 14    4.10   90.0  3.0   80.0   5.6
# 15    9.60  162.0  3.0   80.0   7.6
# 16    2.20   46.0  2.0   70.0  12.6
# 17    5.20   87.0  NaN   80.0  12.1
# 18    1.30   27.0  0.0  100.0  12.7
# 19    1.60   31.0  1.0   60.0  10.3
# 20    3.90  148.0  2.0   80.0   7.7
# 21   76.00  180.0  NaN   90.0  10.9
# 22    7.70  163.0  4.0   80.0   9.8
# 23     NaN    NaN  0.0   70.0   NaN
# 24    1.40   50.0  4.0  100.0  11.1
# ...

# %%
target1=df1['classification']

# %%
feature.isnull().sum()
# Out:
# sc      17
# bu      19
# al      46
# bp      12
# hemo    52
# dtype: int64

# %%
for i in list(feature.columns):
    sns.boxplot(feature[i])
    plt.show()

# %% [markdown]
# THERE ARE MANY OUTLIERS IN KIDNEY_DISEASE FEATURE , HAVE TO HANDLE

# %%
target1.value_counts()
# Out:
# classification
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %% [markdown]
# WE HAVE TO BALANCE THE TARGET COLUMN DATA

# %%
plt.figure(figsize=(20,20))
corr1=feature.corr()
sns.heatmap(corr1,annot=True,cmap='rainbow')
# Out:
# <Axes: >

# %% [markdown]
# HERE WE CAN GET RANGE OF MINMAXSCALER - [-6 TO 1]

# %% [markdown]
# EDA FOR KIDNEY COMPLETED

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# LIVER DISEASE'S EDA

# %%
df2=pd.read_csv(r"C:\Users\firea\Downloads\indian_liver_patient - indian_liver_patient.csv")

# %%
df2.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
for i in list(df2.columns):
    sns.boxplot(df2[i])
    plt.show()

# %% [markdown]
# OUTLIERS SHOULD BE HANDLED

# %%
feature2=df2[['Total_Bilirubin','Direct_Bilirubin','Aspartate_Aminotransferase','Alkaline_Phosphotase','Albumin']]
target2=df2['Dataset']

# %%
feature2
# Out:
#      Total_Bilirubin  Direct_Bilirubin  Aspartate_Aminotransferase  Alkaline_Phosphotase  Albumin
# 0                0.7               0.1                          18                   187      3.3
# 1               10.9               5.5                         100                   699      3.2
# 2                7.3               4.1                          68                   490      3.3
# 3                1.0               0.4                          20                   182      3.4
# 4                3.9               2.0                          59                   195      2.4
# ..               ...               ...                         ...                   ...      ...
# 578              0.5               0.1                          34                   500      1.6
# 579              0.6               0.1                          31                    98      3.2
# 580              0.8               0.2                          49                   245      3.2
# ...

# %%
plt.figure(figsize=(20,20))
corr2=feature2.corr()
sns.heatmap(corr2,annot=True,cmap='rainbow')
# Out:
# <Axes: >

# %% [markdown]
# WE HAVE GOT THE RANGE FOR MINMAXSCALER[-0.2,1]

# %% [markdown]
# CHECKING THE TARGET DATA IS BALANCED OR NOT

# %%
target2.value_counts()
# Out:
# Dataset
# 1    416
# 2    167
# Name: count, dtype: int64

# %% [markdown]
# TARGET IS IMBALANCED..WE HAVE TO BALANCE

# %% [markdown]
# EDA FOR KIDNEY COMPLETED
